# %%
#upload a CSV file
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1738858-1317-4beb-854f-61bd867ba536" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1738858-1317-4beb-854f-61bd867ba536">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'Credit_Card_Applications.csv': b'CustomerID,A1,A2,A3,A4,A5,A6,A7,A8,A9,A10,A11,A12,A13,A14,Class\r\n15776156,1,22.08,11.46,2,4,4,1.585,0,0,0,1,2,100,1213,0\r\n15739548,0,22.67,7,2,8,4,0.165,0,0,0,0,2,160,1,0\r\n15662854,0,29.58,1.75,1,4,4,1.25,0,0,0,1,2,280,1,0\r\n15687688,0,21.67,11.5,1,5,3,0,1,1,11,1,2,0,1,1\r\n15715750,1,20.17,8.17,2,6,4,1.96,1,1,14,0,2,60,159,1\r\n15571121,0,15.83,0.585,2,8,8,1.5,1,1,2,0,2,100,1,1\r\n15726466,1,17.42,6.5,2,3,4,0.125,0,0,0,0,2,60,101,0\r\n15660390,0,58.67,4.46,2,11,8,3.04,1,1,6,0,2,43,561,1\r\n15663942,1,27.83,1,1,2,8,3,0,0,0,0,2,176,538,0\r\n15638610,0,55.75,7.08,2,4,8,6.75,1,1,3,1,2,100,51,0\r\n15644446,1,33.5,1.75,2,14,8,4.5,1,1,4,1,2,253,858,1\r\n15585892,1,41.42,5,2,11,8,5,1,1,6,1,2,470,1,1\r\n15609356,1,20.67,1.25,1,8,8,1.375,1,1,3,1,2,140,211,0\r\n15803378,1,34.92,5,2,14,8,7.5,1,1,6,1,2,0,1001,1\r\n15599440,1,58.58,2.71,2,8,4,2.415,0,0,0,1,2,320,1,0\r\n15692408,1,48.08,6.04,2,4,4,0.04,0,0,0,0,2,0,2691,1\r\n15683168,1,29.58,4.5,2,9,4,7.5,1
# ...

# %%
#Mounting the drive.
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
#Get information related to dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
#check column names from datset
dataset.columns
# Out:
# Index(['CustomerID', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9',
#        'A10', 'A11', 'A12', 'A13', 'A14', 'Class'],
#       dtype='object')

# %%
#Find out math data/description from dataset
dataset.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# ...

# %%
#To read a data cell from a selected a row or column
#loc-iloc
#dframe.loc(rows,columnnames)
dataset.loc[0]
# Out:
# CustomerID    1.577616e+07
# A1            1.000000e+00
# A2            2.208000e+01
# A3            1.146000e+01
# A4            2.000000e+00
# A5            4.000000e+00
# A6            4.000000e+00
# A7            1.585000e+00
# A8            0.000000e+00
# A9            0.000000e+00
# A10           0.000000e+00
# A11           1.000000e+00
# A12           2.000000e+00
# A13           1.000000e+02
# A14           1.213000e+03
# Class         0.000000e+00
# Name: 0, dtype: float64

# %%
dataset.loc[0,'A1']
# Out:
# 1

# %%
dataset.loc[[0,2,5],['A11','A2','A3']]
# Out:
#    A11     A2      A3
# 0    1  22.08  11.460
# 2    1  29.58   1.750
# 5    0  15.83   0.585
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['A11'].plot(kind='hist', bins=20, title='A11')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['A2'].plot(kind='hist', bins=20, title='A2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['A3'].plot(kind='hist', bins=20, title='A3')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='A11', y='A2', s=32, alpha=.8)
# ...

# %%
dataset.iloc[[0,2,4],[11,3,6]]
# Out:
#    A11     A3  A6
# 0    1  11.46   4
# 2    1   1.75   4
# 4    0   8.17   4

# %%
dataset.loc[1,'A4']=32

# %%
dataset.loc[1,'A4']
# Out:
# 32
